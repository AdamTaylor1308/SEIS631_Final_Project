# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df18_23 = pd.read_csv('../Data/ProducedData/refined_df18_23.csv')

# %%
df18_23.groupby('POVERTY3')['ALDAYPWK'].mean()
# Out:
# POVERTY3
# 1.0    2.491875
# 2.0    2.621997
# 3.0    2.902235
# Name: ALDAYPWK, dtype: float64

# %%
df18_23.groupby('POVERTY3')['ALCYRTOT'].mean()
# Out:
# POVERTY3
# 1.0    127.623925
# 2.0    135.070952
# 3.0    150.441271
# Name: ALCYRTOT, dtype: float64
